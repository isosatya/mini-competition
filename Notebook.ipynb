# %%
import pandas as pd
import numpy as np
# Out:
# The kernel failed to start as the Python Environment 'minicomp (Python 3.12.10)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
